# %%
import pandas as pd

# %%
data = pd.read_csv('./result_detail_final.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\admin\Downloads\Laptop-EDA\scraped_data\code\.ipynb_checkpoints\FPTshopScraped-Cleaning-checkpoint.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/Laptop-EDA/scraped_data/code/.ipynb_checkpoints/FPTshopScraped-Cleaning-checkpoint.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> data = pd.read_csv('./result_detail_final.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/admin/Downloads/Laptop-EDA/scraped_data/code/.ipynb_checkpoints/FPTshopScraped-Cleaning-checkpoint.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> data.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './result_detail_final.csv'

# %%
data[['Brand', 'Series']] = data.name.str.split(n = 1, expand=True)
data = data.drop('name', 1)
data.head()
# Out:
#                PN  rating  rating_count     price                     CPU  \
# NH.QD9SV.001  5.0     1.0         588.0  28499000  Intel Core i7 - 11800H
# 852VN         5.0     1.0         313.0  18799000  Intel Core i5 - 1155G7
# P112F001      5.0     1.0         109.0  15299000  Intel Core i3 - 1115G4
# V5I3001W      5.0     2.0         775.0  15599000  Intel Core i3 - 1115G4
# 82H80040VN    5.0     4.0         362.0  14999000  Intel Core i3 - 1115G4
#
#                RAM RAM_upgradable                            GPU battery_wh  \
# NH.QD9SV.001  8 GB            Yes  NVIDIA GeForce RTX 3050Ti 4GB         --
# 852VN         8 GB            Yes         Intel Iris Xe Graphics       65 W
# P112F001      4 GB            Yes             Intel UHD Graphics       65 W
# V5I3001W      8 GB            Yes             Intel UHD Graphics       45 W
# 82H80040VN    8 GB            Yes             Intel UHD Graphics         --
#
#               hard_drive  ... length  width height          OS  \
# NH.QD9SV.001  SSD 512 GB  ...  363.4    255   23.9  Windows 10
# 852VN         SSD 512 GB  ...    319    219   16.9  Windows 10
# P112F001      SSD 256 GB  ...  358.5    258   18.9  Windows 10
# V5I3001W      SSD 256 GB  ...    368    249   19.9  Windows 10
# 82H80040VN    SSD 512 GB  ...    359  237.7   19.9  Windows 10
#
#              surface_material release_year               ports keyboard_light  \
# NH.QD9SV.001             Nhựa         2021  [1, 2, 0, 1, 3, 0]            Yes
# 852VN                Kim Loại         2021  [1, 1, 0, 1, 2, 0]            Yes
# P112F001                 Nhựa         2021  [1, 1, 0, 0, 3, 0]            Yes
# V5I3001W                 Nhựa         2021  [1, 2, 1, 0, 3, 0]            Yes
# 82H80040VN        ABS plastic         2021  [1, 1, 0, 1, 2, 0]            Yes
#
#                Brand                                  Series
# NH.QD9SV.001    Acer    Nitro Gaming AN515-57-74NU/i7-11800H
# 852VN            MSI  Modern 14 B11MOU 852VN i5 1155G7/852VN
# P112F001        Dell    Inspiron N3511 i3 1115G4/P112F001ABL
# V5I3001W        Dell                  Vostro V3500 i3 1115G4
# 82H80040VN    Lenovo         IdeaPad Slim 3 15ITL6 i3 1115G4
#
# [5 rows x 26 columns]

# %%
data['RAM'] = data['RAM'].str.split(' ', 1).str[0]
data.head()
# Out:
#                PN  rating  rating_count     price                     CPU RAM  \
# NH.QD9SV.001  5.0     1.0         588.0  28499000  Intel Core i7 - 11800H   8
# 852VN         5.0     1.0         313.0  18799000  Intel Core i5 - 1155G7   8
# P112F001      5.0     1.0         109.0  15299000  Intel Core i3 - 1115G4   4
# V5I3001W      5.0     2.0         775.0  15599000  Intel Core i3 - 1115G4   8
# 82H80040VN    5.0     4.0         362.0  14999000  Intel Core i3 - 1115G4   8
#
#              RAM_upgradable                            GPU battery_wh  \
# NH.QD9SV.001            Yes  NVIDIA GeForce RTX 3050Ti 4GB         --
# 852VN                   Yes         Intel Iris Xe Graphics       65 W
# P112F001                Yes             Intel UHD Graphics       65 W
# V5I3001W                Yes             Intel UHD Graphics       45 W
# 82H80040VN              Yes             Intel UHD Graphics         --
#
#               hard_drive  ... length  width height          OS  \
# NH.QD9SV.001  SSD 512 GB  ...  363.4    255   23.9  Windows 10
# 852VN         SSD 512 GB  ...    319    219   16.9  Windows 10
# P112F001      SSD 256 GB  ...  358.5    258   18.9  Windows 10
# V5I3001W      SSD 256 GB  ...    368    249   19.9  Windows 10
# 82H80040VN    SSD 512 GB  ...    359  237.7   19.9  Windows 10
#
#              surface_material release_year               ports keyboard_light  \
# NH.QD9SV.001             Nhựa         2021  [1, 2, 0, 1, 3, 0]            Yes
# 852VN                Kim Loại         2021  [1, 1, 0, 1, 2, 0]            Yes
# P112F001                 Nhựa         2021  [1, 1, 0, 0, 3, 0]            Yes
# V5I3001W                 Nhựa         2021  [1, 2, 1, 0, 3, 0]            Yes
# 82H80040VN        ABS plastic         2021  [1, 1, 0, 1, 2, 0]            Yes
#
#                Brand                                  Series
# NH.QD9SV.001    Acer    Nitro Gaming AN515-57-74NU/i7-11800H
# 852VN            MSI  Modern 14 B11MOU 852VN i5 1155G7/852VN
# P112F001        Dell    Inspiron N3511 i3 1115G4/P112F001ABL
# V5I3001W        Dell                  Vostro V3500 i3 1115G4
# 82H80040VN    Lenovo         IdeaPad Slim 3 15ITL6 i3 1115G4
#
# [5 rows x 26 columns]

# %%
data[['storage_type', 'storage_size']] = data['hard_drive'].str.split(' ', n = 1, expand = True)
data = data.drop('hard_drive', 1)
data.head()
# Out:
#                PN  rating  rating_count     price                     CPU RAM  \
# NH.QD9SV.001  5.0     1.0         588.0  28499000  Intel Core i7 - 11800H   8
# 852VN         5.0     1.0         313.0  18799000  Intel Core i5 - 1155G7   8
# P112F001      5.0     1.0         109.0  15299000  Intel Core i3 - 1115G4   4
# V5I3001W      5.0     2.0         775.0  15599000  Intel Core i3 - 1115G4   8
# 82H80040VN    5.0     4.0         362.0  14999000  Intel Core i3 - 1115G4   8
#
#              RAM_upgradable                            GPU battery_wh  \
# NH.QD9SV.001            Yes  NVIDIA GeForce RTX 3050Ti 4GB         --
# 852VN                   Yes         Intel Iris Xe Graphics       65 W
# P112F001                Yes             Intel UHD Graphics       65 W
# V5I3001W                Yes             Intel UHD Graphics       45 W
# 82H80040VN              Yes             Intel UHD Graphics         --
#
#              storage_upgradable  ... height          OS surface_material  \
# NH.QD9SV.001                Yes  ...   23.9  Windows 10             Nhựa
# 852VN                       Yes  ...   16.9  Windows 10         Kim Loại
# P112F001                    Yes  ...   18.9  Windows 10             Nhựa
# V5I3001W                    Yes  ...   19.9  Windows 10             Nhựa
# 82H80040VN                  Yes  ...   19.9  Windows 10      ABS plastic
#
#              release_year               ports keyboard_light   Brand  \
# NH.QD9SV.001         2021  [1, 2, 0, 1, 3, 0]            Yes    Acer
# 852VN                2021  [1, 1, 0, 1, 2, 0]            Yes     MSI
# P112F001             2021  [1, 1, 0, 0, 3, 0]            Yes    Dell
# V5I3001W             2021  [1, 2, 1, 0, 3, 0]            Yes    Dell
# 82H80040VN           2021  [1, 1, 0, 1, 2, 0]            Yes  Lenovo
#
#                                               Series storage_type storage_size
# NH.QD9SV.001    Nitro Gaming AN515-57-74NU/i7-11800H          SSD       512 GB
# 852VN         Modern 14 B11MOU 852VN i5 1155G7/852VN          SSD       512 GB
# P112F001        Inspiron N3511 i3 1115G4/P112F001ABL          SSD       256 GB
# V5I3001W                      Vostro V3500 i3 1115G4          SSD       256 GB
# 82H80040VN           IdeaPad Slim 3 15ITL6 i3 1115G4          SSD       512 GB
#
# [5 rows x 27 columns]

# %%
data['screen_size'] = data['screen_size'].str.strip('"')
data['screen_size']
# Out:
# NH.QD9SV.001       15.6
# 852VN              14.0
# P112F001           15.6
# V5I3001W           15.6
# 82H80040VN         15.6
#                    ...
# A515EA-BN1688T     15.6
# 519A7PA            14.0
# NK                 15.6
# P91K5              15.6
# 90NX03A1-M06750    11.6
# Name: screen_size, Length: 141, dtype: object

# %%
data['display_resolution'] = data['display_resolution'].str.split(' ', n = 3).str[0:3].str.join(' ')
data['display_resolution']
# Out:
# NH.QD9SV.001       1920 x 1080
# 852VN              1920 x 1080
# P112F001           1920 x 1080
# V5I3001W           1920 x 1080
# 82H80040VN         1920 x 1080
#                       ...
# A515EA-BN1688T     1920 x 1080
# 519A7PA            1920 x 1080
# NK                  1366 x 768
# P91K5               1366 x 768
# 90NX03A1-M06750     1366 x 768
# Name: display_resolution, Length: 141, dtype: object

# %%
data['display_rating'] = data['display_rating'].str.split(' ', 1).str[0]
data['display_rating']
# Out:
# NH.QD9SV.001       144
# 852VN               60
# P112F001            60
# V5I3001W            60
# 82H80040VN          60
#                   ...
# A515EA-BN1688T      60
# 519A7PA             60
# NK                  60
# P91K5               60
# 90NX03A1-M06750     60
# Name: display_rating, Length: 141, dtype: object

# %%
cols = data.columns.tolist()
print(cols)
# Out:
# ['PN', 'rating', 'rating_count', 'price', 'CPU', 'RAM', 'RAM_upgradable', 'GPU', 'battery_wh', 'storage_upgradable', 'screen_size', 'display_resolution', 'display_rating', 'screen_technology', 'weight', 'length', 'width', 'height', 'OS', 'surface_material', 'release_year', 'ports', 'keyboard_light', 'Brand', 'Series', 'storage_type', 'storage_size']

# %%
cols  = ['PN', 'rating', 'rating_count','Brand', 'Series','price', 'CPU', 
         'RAM', 'RAM_upgradable', 'GPU', 'battery_wh', 'storage_type', 'storage_size',
         'storage_upgradable', 'screen_size', 'display_resolution', 'display_rating', 'screen_technology', 
         'weight', 'length', 'width', 'height', 'OS', 'surface_material', 'release_year', 
         'ports', 'keyboard_light']
data = data.reindex(columns = cols)
data.iloc[0,:]
# Out:
# PN                                                     5.0
# rating                                                 1.0
# rating_count                                         588.0
# Brand                                                 Acer
# Series                Nitro Gaming AN515-57-74NU/i7-11800H
# price                                             28499000
# CPU                                 Intel Core i7 - 11800H
# RAM                                                      8
# RAM_upgradable                                         Yes
# GPU                          NVIDIA GeForce RTX 3050Ti 4GB
# battery_wh                                              --
# storage_type                                           SSD
# storage_size                                        512 GB
# storage_upgradable                                     Yes
# screen_size                                           15.6
# display_resolution                             1920 x 1080
# display_rating                                         144
# screen_technology                              LED-backlit
# weight                                                 2.2
# length                                               363.4
# width                                                  255
# height                                                23.9
# OS                                              Windows 10
# surface_material                                      Nhựa
# release_year                                          2021
# ports                                   [1, 2, 0, 1, 3, 0]
# keyboard_light                                         Yes
# Name: NH.QD9SV.001, dtype: object

# %%
data.head()
# Out:
#                PN  rating  rating_count   Brand  \
# NH.QD9SV.001  5.0     1.0         588.0    Acer
# 852VN         5.0     1.0         313.0     MSI
# P112F001      5.0     1.0         109.0    Dell
# V5I3001W      5.0     2.0         775.0    Dell
# 82H80040VN    5.0     4.0         362.0  Lenovo
#
#                                               Series     price  \
# NH.QD9SV.001    Nitro Gaming AN515-57-74NU/i7-11800H  28499000
# 852VN         Modern 14 B11MOU 852VN i5 1155G7/852VN  18799000
# P112F001        Inspiron N3511 i3 1115G4/P112F001ABL  15299000
# V5I3001W                      Vostro V3500 i3 1115G4  15599000
# 82H80040VN           IdeaPad Slim 3 15ITL6 i3 1115G4  14999000
#
#                                  CPU RAM RAM_upgradable  \
# NH.QD9SV.001  Intel Core i7 - 11800H   8            Yes
# 852VN         Intel Core i5 - 1155G7   8            Yes
# P112F001      Intel Core i3 - 1115G4   4            Yes
# V5I3001W      Intel Core i3 - 1115G4   8            Yes
# 82H80040VN    Intel Core i3 - 1115G4   8            Yes
#
#                                         GPU  ...  \
# NH.QD9SV.001  NVIDIA GeForce RTX 3050Ti 4GB  ...
# 852VN                Intel Iris Xe Graphics  ...
# P112F001                 Intel UHD Graphics  ...
# V5I3001W                 Intel UHD Graphics  ...
# 82H80040VN               Intel UHD Graphics  ...
#
#                                      screen_technology weight length  width  \
# NH.QD9SV.001                               LED-backlit    2.2  363.4    255
# 852VN                                          IPS LCD    1.3    319    219
# P112F001      WVA Anti-glare LED Backlit Narrow Border   1.73  358.5    258
# V5I3001W                        Anti-glare LED-backlit   1.98    368    249
# 82H80040VN                      Anti-glare LED-backlit   1.65    359  237.7
#
#              height          OS surface_material release_year  \
# NH.QD9SV.001   23.9  Windows 10             Nhựa         2021
# 852VN          16.9  Windows 10         Kim Loại         2021
# P112F001       18.9  Windows 10             Nhựa         2021
# V5I3001W       19.9  Windows 10             Nhựa         2021
# 82H80040VN     19.9  Windows 10      ABS plastic         2021
#
#                            ports keyboard_light
# NH.QD9SV.001  [1, 2, 0, 1, 3, 0]            Yes
# 852VN         [1, 1, 0, 1, 2, 0]            Yes
# P112F001      [1, 1, 0, 0, 3, 0]            Yes
# V5I3001W      [1, 2, 1, 0, 3, 0]            Yes
# 82H80040VN    [1, 1, 0, 1, 2, 0]            Yes
#
# [5 rows x 27 columns]

# %%
data.to_csv('result_cleaned.csv')

# %%
df = pd.read_csv('./result_cleaned.csv')
df.head()
# Out:
#      Unnamed: 0   PN  rating  rating_count   Brand  \
# 0  NH.QD9SV.001  5.0     1.0         588.0    Acer
# 1         852VN  5.0     1.0         313.0     MSI
# 2      P112F001  5.0     1.0         109.0    Dell
# 3      V5I3001W  5.0     2.0         775.0    Dell
# 4    82H80040VN  5.0     4.0         362.0  Lenovo
#
#                                    Series     price                     CPU  \
# 0    Nitro Gaming AN515-57-74NU/i7-11800H  28499000  Intel Core i7 - 11800H
# 1  Modern 14 B11MOU 852VN i5 1155G7/852VN  18799000  Intel Core i5 - 1155G7
# 2    Inspiron N3511 i3 1115G4/P112F001ABL  15299000  Intel Core i3 - 1115G4
# 3                  Vostro V3500 i3 1115G4  15599000  Intel Core i3 - 1115G4
# 4         IdeaPad Slim 3 15ITL6 i3 1115G4  14999000  Intel Core i3 - 1115G4
#
#   RAM RAM_upgradable  ...                         screen_technology weight  \
# 0   8            Yes  ...                               LED-backlit    2.2
# 1   8            Yes  ...                                   IPS LCD    1.3
# 2   4            Yes  ...  WVA Anti-glare LED Backlit Narrow Border   1.73
# 3   8            Yes  ...                    Anti-glare LED-backlit   1.98
# 4   8            Yes  ...                    Anti-glare LED-backlit   1.65
#
#   length  width height          OS surface_material release_year  \
# 0  363.4    255   23.9  Windows 10             Nhựa         2021
# 1    319    219   16.9  Windows 10         Kim Loại         2021
# 2  358.5    258   18.9  Windows 10             Nhựa         2021
# 3    368    249   19.9  Windows 10             Nhựa         2021
# 4    359  237.7   19.9  Windows 10      ABS plastic         2021
#
#                 ports keyboard_light
# 0  [1, 2, 0, 1, 3, 0]            Yes
# 1  [1, 1, 0, 1, 2, 0]            Yes
# 2  [1, 1, 0, 0, 3, 0]            Yes
# 3  [1, 2, 1, 0, 3, 0]            Yes
# 4  [1, 1, 0, 1, 2, 0]            Yes
#
# [5 rows x 28 columns]
